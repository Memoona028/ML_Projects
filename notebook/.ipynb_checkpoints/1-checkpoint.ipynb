# %%
print("hi")
# Out:
# Running cells with 'c:\ML_Projects\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\ML_Projects\venv ipykernel --update-deps --force-reinstall'

# %%
conda install -p c:\ML_Projects\venv ipykernel --update-deps --force-reinstall
# Out:
# Running cells with 'c:\ML_Projects\venv\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\ML_Projects\venv ipykernel --update-deps --force-reinstall'
